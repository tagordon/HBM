# %%
import os
os.environ['EXO_LD_PATH'] = '/Users/tylergordon/research/exotic_ld_data'

import pickle
import numpy as np
import matplotlib.pyplot as plt
from multiprocess import Pool

import sys
sys.path.append('../get_planet_params/')
from fit_wlc import fit, load_priors
import distributions
import argparse

# %%
import pickle

# %%
priors_and_params = load_priors('TOI-421 b', ('carleo', '2020'), ('carleo', '2020'))

# %%
priors_and_params[0]['orbincl'].init
# Out:
# 85.68

# %%
i1 = 2
i2 = 20

norm1 = np.median(res_nrs2['lightcurves'][0].T[i1][:200])
norm2 = np.median(res_nrs2['lightcurves'][0].T[i2][:200])

fig, axs = plt.subplots(2, 1, figsize=(10, 5), sharex=True)

axs[0].plot(res_nrs2['lightcurves'][0].T[i1] / norm1, 'r.', alpha=0.3);
axs[0].plot(res_nrs2['lightcurves'][0].T[i2] / norm2, 'k.', alpha=0.3);

axs[1].plot(res_nrs2['lightcurves'][0].T[i1] - res_nrs2['lightcurves'][0].T[i2], '.')

# %%
plt.plot(res_nrs2['posteriors'][2]['r0']);
plt.plot(res_nrs2['posteriors'][20]['r0']);

# %%
plt.plot([np.median(r['r0']) for r in res_nrs2['posteriors']], '.')

# %%
disp_filt_options = [
    'PRISM/CLEAR',
    'G395H/F290LP_NRS1',
    'G395H/F290LP_NRS2',
    'G235H/F170LP_NRS1',
    'G235H/F170LP_NRS2',
    'G140H/F100LP_NRS1',
    'G140H/F100LP_NRS2',
    'G140H/F070LP',
    'G395M/F290LP',
    'G235M/F170LP',
    'G140M/F100LP',
    'G140M/F070LP'
]

wav_ranges = [
    (0.6, 5.3),
    (2.87, 3.69),
    (3.79, 5.14),
    (1.66, 2.18),
    (2.24, 3.05),
    (0.97, 1.3),
    (1.34, 1.82),
    (0.81, 1.27),
    (2.87, 5.10),
    (1.66, 3.07),
    (0.97, 1.84),
    (0.70, 1.27)
]

# %%
wav_ranges[disp_filt_options.index('G235H/F170LP_NRS1')]

# %%
fig, axs = plt.subplots(1, 2)

# %%
len(axs.shape)

# %%
x, y = np.random.randn(2, 10)
z = np.random.randn(10)
xerr_plus, yerr_plus = np.abs(np.random.randn(2, 10)) * 0.3
xerr_minus, yerr_minus = np.abs(np.random.randn(2, 10)) * 0.3

x_upper_lim = np.array([3, 4, 5])
y_up

y_upper_lim = np.array([2, 3, 4])

# %%
plt.errorbar(x, y, xerr=(xerr_minus, xerr_plus), yerr=(yerr_minus, yerr_plus), ls='none', color='k', capsize=4, uplims=True)
plt.scatter(x, y, c=z, zorder=10, edgecolor='k', s=50)

# %%
x = np.arange(10, dtype=np.float64)
y = np.random.randint(10, size=10)
x[0] = -1
x[2] = -1
x[8] = -1
x

# %%
x[x == -1] = np.nan
x

# %%
y = np.ones(10)
y

# %%
plt.plot(x, y, '.')

# %%
type(np.pi)

# %%
np.int64(np.pi)
