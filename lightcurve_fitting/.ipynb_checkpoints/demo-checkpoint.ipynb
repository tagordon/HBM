# %%
import os
os.environ['EXO_LD_PATH'] = '/Users/tylergordon/research/exotic_ld_data'

import pickle
import numpy as np
import matplotlib.pyplot as plt
from multiprocess import Pool

import sys
sys.path.append('../get_planet_params/')
from fit_wlc import fit, load_priors_and_parameters
import distributions

# load priors 
priors_d, st_params = load_priors_and_parameters(
    'TOI-270 d', 
    ('van_eylen', '2021'), 
    ('van_eylen', '2021')
)

priors_b, st_params = load_priors_and_parameters(
    'TOI-270 b', 
    ('van_eylen', '2021'), 
    ('van_eylen', '2021')
)

priors_c, st_params = load_priors_and_parameters(
    'TOI-270 c', 
    ('van_eylen', '2021'), 
    ('van_eylen', '2021')
)

# change priors or initial points if necessary 
# e.g. priors['orbeccen'] = distributions.uniform(0, 1, init=0.01)

# %%
# build control dictionaries for each lightcurve (just one if not using G395H)
control_dict_nrs1 = {
    
    # eureka or jedi
    'pipeline': 'eureka',
    
    'priors': [priors_d, priors_b, priors_c],
    'stellar_parameters': st_params,
    
    # this is the directory that all the input files are located in
    'data_directories': [
        '/Users/tylergordon/research/HBM/volga/TOI-270_d/4098_17/S3_nrs1_ap4_bg7_SpecData.h5',
        '/Users/tylergordon/research/HBM/volga/TOI-270_d/4098_16/S3_nrs1_ap3_bg8_SpecData.h5'
    ],
    
    # use this to mask any columns that look like they got a bad background subtraction
    'columns_to_mask': [],
    
    # for G395H, will need to add support for other detectors/dispersers 
    'detector': 'nrs1',
    
    # number of MCMC samples and number to crop off beginning of chains for burn-in
    'samples': 1_000,
    'burnin': 500,
    
    # number of processors to use: 2 seems to be best on my computer for some reason.
    'num_proc': 2,
    
    # order of a polynomial trend for the out-of-transit flux 
    'polyorder': 1,
    
    # whether to show the MCMC progress bar or not 
    'show_progress_bar': True,
    
    # number of processors to use for spectral lightcurve fitting 
    'num_proc_slc': 12,
    
    # number of samples for white lightcurve fitting
    'samples_slc': 1_000
}

control_dict_nrs2 = {
    'pipeline': 'eureka',
    'priors': [priors_d, priors_b, priors_c],
    'stellar_parameters': st_params,
    'data_directories': [
        '/Users/tylergordon/research/HBM/volga/TOI-270_d/4098_17/S3_nrs2_ap3_bg6_SpecData.h5',
        '/Users/tylergordon/research/HBM/volga/TOI-270_d/4098_16/S3_nrs2_ap3_bg7_SpecData.h5'
    ],
    'columns_to_mask': [],
    'detector': 'nrs2',
    'samples': 1_000,
    'burnin': 500,
    'num_proc': 2,
    'polyorder': 1,
    'show_progress_bar': True,
    'num_proc_slc': 12,
    'samples_slc': 1_000
}

# %%
import imp
import fit_wlc
import transit
import wlc_utils
import utils
imp.reload(utils)
imp.reload(transit)
imp.reload(wlc_utils)
imp.reload(fit_wlc)

# plot the white lightcurves along with the model corresponding to the initial parameters for the MCMC fit 
# also plots the time vs. x-pixel images for identifying bad columns or other artifacts 

from fit_wlc import check_initial_state, prep_data

times_nrs1, spects_nrs1, errs_nrs1, _, specs_nrs1, flux_nrs1, _= prep_data(control_dict_nrs1)
initial_models_nrs1, masks_nrs1 = check_initial_state(control_dict_nrs1)

times_nrs2, spects_nrs2, errs_nrs2, _, specs_nrs2, flux_nrs2, _ = prep_data(control_dict_nrs2)
initial_models_nrs2, masks_nrs2 = check_initial_state(control_dict_nrs2)

for i in range(len(times_nrs1)):
    
    fig, axs = plt.subplots(2, 2, figsize=(20, 5), gridspec_kw={'hspace': 0.2, 'wspace': 0.1, 'width_ratios':(0.2, 0.8)})
    
    axs[0, 0].plot(times_nrs1[i], initial_models_nrs1[i])
    axs[0, 0].plot(times_nrs1[i][~masks_nrs1[i]], flux_nrs1[i][~masks_nrs1[i]], 'k.', markersize=0.2)
    axs[0, 0].plot(times_nrs1[i][masks_nrs1[i]], flux_nrs1[i][masks_nrs1[i]], 'r.', markersize=0.2)
    axs[0, 1].imshow(spects_nrs1[i] / np.nanmedian(spects_nrs1[i], axis=0), aspect='auto', vmin=0.99, vmax=1.01)

    axs[1, 0].plot(times_nrs2[i], initial_models_nrs2[i])
    axs[1, 0].plot(times_nrs2[i][~masks_nrs2[i]], flux_nrs2[i][~masks_nrs2[i]], 'k.', markersize=0.2)
    axs[1, 0].plot(times_nrs2[i][masks_nrs2[i]], flux_nrs2[i][masks_nrs2[i]], 'r.', markersize=0.2)
    axs[1, 1].imshow(spects_nrs2[i] / np.nanmedian(spects_nrs2[i], axis=0), aspect='auto', vmin=0.99, vmax=1.01)

# %%
import imp
import fit_wlc
import wlc_utils
imp.reload(wlc_utils)
imp.reload(fit_wlc)
from fit_wlc import fit

# run the fits once everything looks good 

wlc_res_nrs1 = fit(control_dict_nrs1, samples=100, burnin=0)
wlc_res_nrs2 = fit(control_dict_nrs2, samples=100, burnin=0)
# Out:
#   5%| | 5/100 [00:01Process SpawnPoolWorker-52:
#   5%| | 5/100 [00:01Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/connection.py", line 433, in _recv_bytes
#     buf = self._recv(4)
#
#       ^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/connection.py", line 398, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/fit_wlc.py", line 236, in log_prob
#     total_prob += lps[i](np.concatenate([op, transit_params]))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/wlc_utils.py", line 212, in log_prob
#     mu = (1 + keplerian_transit(time, n, p)) * trend
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/transit.py", line 30, in keplerian_transit
#     m += batman.TransitModel(param_obj, t, fac=0.01).light_curve(param_obj)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/batman/transitmodel.py", line 207, in __init__
#     self.ds = _rsky._rsky(
#               ^^^^^^^^^^^^
# KeyboardInterrupt
# Process SpawnPoolWorker-51:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/fit_wlc.py", line 236, in log_prob
#     total_prob += lps[i](np.concatenate([op, transit_params]))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/wlc_utils.py", line 212, in log_prob
#     mu = (1 + keplerian_transit(time, n, p)) * trend
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/tylergordon/research/HBM/lightcurve_fitting/transit.py", line 30, in keplerian_transit
#     m += batman.TransitModel(param_obj, t, fac=0.01).light_curve(param_obj)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/batman/transitmodel.py", line 207, in __init__
#     self.ds = _rsky._rsky(
#               ^^^^^^^^^^^^
# KeyboardInterrupt
# -24675.126998256343
# -75384.70989267572
# -24797.958471317805
# -75762.26328913336
# -24564.795857639667
# -75109.48133935395
# -24679.47984007003
# -75029.34388957657
# -24925.889139253806
# -74395.75147682629
# -24796.86645110679
# -75090.44575077441
# -24716.39901900575
# -74554.9577535045
# -24727.91457310722
# -74640.09808244354
# -24822.64505763413
# -74749.43309317119
# -24842.54191035664
# -75046.75173103172
# -24620.82540572028
# -74506.90118655827
# -24918.556639857008
# -74501.21466976183
# -24692.058490894302
# -75295.81035441722
# -24799.621605836895
# -74931.59972851063
# -24667.240980854705
# -74305.40420645499
# -24746.639354640927
#   1.96220830e-01  1.31035992e-01  7.69055041e-02  1.86621612e+00
#   2.02843097e+04  1.03941742e+08 -3.34323145e+03  2.84264909e-02
#   1.96150976e-01  1.31162759e-01  7.68042972e-02  1.86636631e+00
#   5.16650341e-02  1.13795747e+01  4.10153586e+01  8.97301313e+01
#   3.20236202e-02 -5.99999549e+00  2.90711883e-02  3.36015640e+00
#   1.81865982e+01  8.93898287e+01  3.39789624e-02  7.50479814e-05
#   5.70043708e-02  5.66057437e+00  2.57469555e+01  8.93600929e+01
#   2.68058747e-02  9.99996030e+00]
#   args: []
#   kwargs: {}
#   exception:

# %%
from fit_wlc import get_model_samples

for res_nrs1, res_nrs2 in zip(wlc_res_nrs1, wlc_res_nrs2):
    
    fig, axs = plt.subplots(2, 2, figsize=(15, 4), gridspec_kw={'height_ratios': (0.6, 0.4), 'hspace': 0.0, 'wspace': 0.15}, sharex=True)

    axs[0, 0].annotate('NRS1', fontsize=20, xy=(0.05, 0.1), xycoords='axes fraction')
    axs[0, 1].annotate('NRS2', fontsize=20, xy=(0.05, 0.1), xycoords='axes fraction')
    
    models_nrs1 = get_model_samples(res_nrs1, n=100)

    axs[0, 0].plot(res_nrs1['time'], res_nrs1['flux'], '.', color=plt.cm.rainbow(0.1), markersize=1.0)
    [axs[0, 0].plot(res_nrs1['time'], m, color='k', alpha=0.3) for m in models_nrs1];
    axs[1, 0].plot(res_nrs1['time'], res_nrs1['flux'] - np.mean(models_nrs1, axis=0), '.', color=plt.cm.rainbow(0.1), markersize=1.0)

    models_nrs2 = get_model_samples(res_nrs2, n=100)

    axs[0, 1].plot(res_nrs2['time'], res_nrs2['flux'], '.', color=plt.cm.rainbow(0.1), markersize=1.0)
    [axs[0, 1].plot(res_nrs2['time'], m, color='k', alpha=0.3) for m in models_nrs2];
    axs[1, 1].plot(res_nrs2['time'], res_nrs2['flux'] - np.mean(models_nrs2, axis=0), '.', color=plt.cm.rainbow(0.1), markersize=1.0)

# %%
import imp
import fit_slc
imp.reload(fit_slc)
from fit_slc import fit

slc_res_nrs1 = fit(wlc_res_nrs1)
slc_res_nrs2 = fit(wlc_res_nrs2)

# %%
binned_wavs = np.concatenate([slc_res_nrs1['wavs'], slc_res_nrs2['wavs']])
depths = np.array([np.median(p['r0'][500:]) for p in slc_res_nrs1['posteriors'] + slc_res_nrs2['posteriors']])
errs = np.array([np.std(p['r0'][500:]) for p in slc_res_nrs1['posteriors'] + slc_res_nrs2['posteriors']])

plt.plot(binned_wavs, depths**2 * 1e6, 'ko')
plt.errorbar(binned_wavs, depths**2 * 1e6, yerr=errs * 2 * depths * 1e6, ls='none', color='k')

# %%
binned_wavs = np.concatenate([slc_res_nrs1['wavs'], slc_res_nrs2['wavs']])
depths = np.array([np.median(p['r1'][5000:]) for p in slc_res_nrs1['posteriors'] + slc_res_nrs2['posteriors']])
errs = np.array([np.std(p['r1'][5000:]) for p in slc_res_nrs1['posteriors'] + slc_res_nrs2['posteriors']])

plt.plot(binned_wavs, depths**2 * 1e6, 'ko')
plt.errorbar(binned_wavs, depths**2 * 1e6, yerr=errs * 2 * depths * 1e6, ls='none', color='k')

# %%
[len(x) > 0 for x in [[], []]]
